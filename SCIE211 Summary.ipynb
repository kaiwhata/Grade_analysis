# %% [markdown]
# ### Here we present data for SCIE211 and SCIE201 for the period between 2011 and 2014 inclusive. The 2014 course has yet to finish and so the data is to be taken as indicative only at this stage

# %%
#load display libraries
from IPython.display import Image

# %% [markdown]
# # Summary Table

# %% [markdown]
# <table><tr><th>Year</th><th>Paper</th><th>Enrolments</th><th>Withdrawn</th><th>Pass</th><th>Fail</th><th>Domestic</th><th>International</th><th>Male</th><th>Female</th><th>Excluded (no grade data)</th></tr><tr><td>2011</td><td>SCIE201</td><td>36</td><td>3</td><td>34</td><td>2</td><td>35</td><td>1</td><td>17</td><td>19</td><td>3</td></tr><tr><td>2012</td><td>SCIE201</td><td>113</td><td>3</td><td>106</td><td>7</td><td>93</td><td>20</td><td>64</td><td>49</td><td>7</td></tr><tr><td>2013</td><td>SCIE211</td><td>179</td><td>6</td><td>140</td><td>39</td><td>165</td><td>14</td><td>94</td><td>85</td><td>14</td></tr><tr><td>2014</td><td>SCIE211</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>222</td></tr></table>

# %% [markdown]
# # Enrolments and Pass Rate

# %%
enrol = Image(filename='enrol_pass.png')
display(enrol)

# %% [markdown]
# # Course Grade Distribution per year

# %% [markdown]
# # i2011 = Image(filename='2011.png')
# i2012 = Image(filename='2012.png')
# i2013 = Image(filename='2013.png')
# #2014 = Image(filename='2014.png')
#
#
# display(2011)
# display(2012)
# display(2013)

# %% [markdown]
# # Gender Balance

# %%
gender = Image(filename='gender.png')
display(gender)

# %% [markdown]
# # Domestic/International Student Balance

# %%
domint = Image(filename='dom_int.png')
display(domint)

# %% [markdown]
# Raw Figures are available as shown below

# %%
# %%bash
# ls *.png
# Out:
# dom_int.png
# enrol_pass.png
# gender.png
